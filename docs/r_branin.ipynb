# %% [markdown]
# # R Branin
#
# This notebook is an example of a single objective R model optimization using a branin synthetic function.
#
# See the folder `r_branin` for the R script and the configuration file.

# %%
# This notebook uses hidden cells to import and display things so
# that it can be ran regullary to make sure the documentation
# is up to date and not broken (as opposed to a markdown file
# that would have an exmaple written once and get out of date
# as the code base changes)

# These hidden cells are only responsible for rerunning
# the documentation to ensure it is correct.
# the actual relavent part of the documentation
# are the non hidden parts

# %%
import pathlib

from IPython.display import Code

boa_paper_dir = pathlib.Path().resolve().parent
r_dir = boa_paper_dir / "r_branin"
config_path = r_dir / "config.yaml"
run_model_script = r_dir / "run_model.R"

# %% [markdown]
# ## Configuration File Overview
#
# config.yaml

# %%
Code(config_path)
# Out:
# objective:
#     metrics:
#         # List all of your metrics
#         -   metric: branin
#             metric_type: synthetic_metric
#             minimize: true
#
# # List all parameters
# parameters:
#     x0:
#         type: range
#         bounds: [-5, 10]
#         value_type: float
#     x1:
#         type: range
#         bounds: [0, 15]
#         value_type: float
#
# # number of trials and other general run settings
# scheduler:
#     n_trials: 15
#
# # Which script to run and what to write files out as
# script_options:
#     run_model: Rscript run_model.R

# %% [markdown]
# ## Run Model Wrapper Script
#
# run_model.R

# %%
Code(run_model_script)
# Out:
# library(jsonlite)
#
# trial_dir <- commandArgs(trailingOnly=TRUE)[1]
# data <- read_json(path=file.path(trial_dir, "parameters.json"))
# write(toJSON(list(branin=data), auto_unbox=TRUE), file.path(trial_dir, "output.json"))

# %% [markdown]
# ## Running our script
#
# To run our script we just need to path the config file to BOA's CLI
#
# ```python
# python -m boa --config-file path/to/config.yaml
# ```
#
# or
#
# ```python
# python -m boa -c path/to/config.yaml
# ```

# %%
output = !python -m boa -c {config_path}  # we capture ipython terminal output to python variable
o = "\n".join(ln for ln in output)  # it comes in as a list, we convert to string
o = o.replace(str(r_dir),  "[/path/to/your/dir/]")  # replace the actual dir with a stand in for privacy reasons
Code(o)
# Out:
# [WARNING 07-12 18:25:57] ax.service.utils.with_db_settings_base: Ax currently requires a sqlalchemy version below 2.0. This will be addressed in a future release. Disabling SQL storage in Ax for now, if you would like to use SQL storage please install Ax with mysql extras via `pip install ax-platform[mysql]`.
# [INFO 07-12 18:25:58] ax.service.utils.instantiation: Created search space: SearchSpace(parameters=[RangeParameter(name='x0', parameter_type=FLOAT, range=[-5.0, 10.0]), RangeParameter(name='x1', parameter_type=FLOAT, range=[0.0, 15.0])], parameter_constraints=[]).
# [INFO 07-12 18:25:58] ax.modelbridge.dispatch_utils: Using Models.BOTORCH_MODULAR since there are more ordered parameters than there are categories for the unordered categorical parameters.
# [INFO 07-12 18:25:58] ax.modelbridge.dispatch_utils: Calculating the number of remaining initialization trials based on num_initialization_trials=None max_initialization_trials=None num_tunable_parameters=2 num_trials=None use_batch_trials=False
# [INFO 07-12 18:25:58] ax.modelbridge.dispatch_utils: calculated num_initialization_trials=5
# [INFO 07-12 18:25:58] ax.modelbridge.dispatch_utils: num_completed_initialization_trials=0 num_remaining_initialization_trials=5
# [INFO 07-12 18:25:58] ax.modelbridge.dispatch_utils: `verbose`, `disable_progbar`, and `jit_compile` are not yet supported when using `choose_generation_strategy` with ModularBoTorchModel, dropping these arguments.
# [INFO 07-12 18:25:58] ax.modelbridge.dispatch_utils: Using Bayesian Optimization generation strategy: GenerationStrategy(name='Sobol+BoTorch', steps=[Sobol for 5 trials, BoTorch for subsequent trials]). Iterations after 5 will take longer to generate due to model-fitting.
# [INFO 07-12 18:25:58] Scheduler: `Scheduler` requires experiment to have immutable search space and optimization config. Setting property immutable_search_space_and_opt_config to `True` on experiment.
# [INFO 2024-07-12 18:25:58,430 MainProcess MainThread {controller.py:165}] boa:
#
# ##############################################
#
#
# BOA Experiment Run
# Output Experiment Dir: [/path/to/your/dir/]/boa_runs_20240712T182558
# Scheduler File Path: [/path/to/your/dir/]/boa_runs_20240712T182558/scheduler.json
# Optimization CSV File Path: [/path/to/your/dir/]/boa_runs_20240712T182558/optimization.csv
# Start Time: 20240712T182558
# Version: 0.10.3.dev20+gb114a5b.d20240705
#
# ##############################################
#
# [INFO 07-12 18:25:58] Scheduler: Running trials [0]...
# [INFO 2024-07-12 18:25:58,474 MainProcess ThreadPoolExecutor-0_0 {script_wrapper.py:322}] boa: Rscript run_model.R
# [INFO 2024-07-12 18:25:58,477 MainProcess ThreadPoolExecutor-0_0 {script_wrapper.py:328}] boa: {'config_path': PosixPath('[/path/to/your/dir/]/config.yaml'), 'config_dir': PosixPath('[/path/to/your/dir/]'), 'config_dir_name': 'r_branin', 'config_file_name': 'config.yaml', 'x0': 0.37698596715927124, 'x1': 3.778756856918335, 'trial_dir': PosixPath('[/path/to/your/dir/]/boa_runs_20240712T182558/000000')}
# [INFO 2024-07-12 18:25:58,478 MainProcess ThreadPoolExecutor-0_0 {script_wrapper.py:330}] boa: Rscript run_model.R
# [INFO 07-12 18:25:59] Scheduler: Running trials [1]...
# [INFO 2024-07-12 18:25:59,553 MainProcess ThreadPoolExecutor-1_0 {script_wrapper.py:322}] boa: Rscript run_model.R
# [INFO 2024-07-12 18:25:59,553 MainProcess ThreadPoolExecutor-1_0 {script_wrapper.py:328}] boa: {'config_path': PosixPath('[/path/to/your/dir/]/config.yaml'), 'config_dir': PosixPath('[/path/to/your/dir/]'), 'config_dir_name': 'r_branin', 'config_file_name': 'config.yaml', 'x0': -0.6389234121888876, 'x1': 9.291526596061885, 'trial_dir': PosixPath('[/path/to/your/dir/]/boa_runs_20240712T182558/000001')}
# [INFO 2024-07-12 18:25:59,554 MainProcess ThreadPoolExecutor-1_0 {script_wrapper.py:330}] boa: Rscript run_model.R
# [INFO 07-12 18:25:59] Scheduler: Running trials [2]...
# [INFO 2024-07-12 18:25:59,577 MainProcess ThreadPoolExecutor-2_0 {script_wrapper.py:322}] boa: Rscript run_model.R
# [INFO 2024-07-12 18:25:59,577 MainProcess ThreadPoolExecutor-2_0 {script_wrapper.py:328}] boa: {'config_path': PosixPath('[/path/to/your/dir/]/config.yaml'), 'config_dir': PosixPath('[/path/to/your/dir/]'), 'config_dir_name': 'r_branin', 'config_file_name': 'config.yaml', 'x0': 0.8284004870802164, 'x1': 9.188861539587379, 'trial_dir': PosixPath('[/path/to/your/dir/]/boa_runs_20240712T182558/000002')}
# [INFO 2024-07-12 18:25:59,578 MainProcess ThreadPoolExecutor-2_0 {script_wrapper.py:330}] boa: Rscript run_model.R
# [INFO 07-12 18:26:00] Scheduler: Running trials [3]...
# [INFO 2024-07-12 18:26:00,605 MainProcess ThreadPoolExecutor-3_0 {script_wrapper.py:322}] boa: Rscript run_model.R
# [INFO 2024-07-12 18:26:00,607 MainProcess ThreadPoolExecutor-3_0 {script_wrapper.py:328}] boa: {'config_path': PosixPath('[/path/to/your/dir/]/config.yaml'), 'config_dir': PosixPath('[/path/to/your/dir/]'), 'config_dir_name': 'r_branin', 'config_file_name': 'config.yaml', 'x0': 0.9147671004757285, 'x1': 0.6087045231834054, 'trial_dir': PosixPath('[/path/to/your/dir/]/boa_runs_20240712T182558/000003')}
# [INFO 2024-07-12 18:26:00,608 MainProcess ThreadPoolExecutor-3_0 {script_wrapper.py:330}] boa: Rscript run_model.R
# [INFO 07-12 18:26:01] Scheduler: Running trials [4]...
# [INFO 2024-07-12 18:26:01,648 MainProcess ThreadPoolExecutor-4_0 {script_wrapper.py:322}] boa: Rscript run_model.R
# [INFO 2024-07-12 18:26:01,649 MainProcess ThreadPoolExecutor-4_0 {script_wrapper.py:328}] boa: {'config_path': PosixPath('[/path/to/your/dir/]/config.yaml'), 'config_dir': PosixPath('[/path/to/your/dir/]'), 'config_dir_name': 'r_branin', 'config_file_name': 'config.yaml', 'x0': 2.9885737458243966, 'x1': 3.283813144080341, 'trial_dir': PosixPath('[/path/to/your/dir/]/boa_runs_20240712T182558/000004')}
# [INFO 2024-07-12 18:26:01,651 MainProcess ThreadPoolExecutor-4_0 {script_wrapper.py:330}] boa: Rscript run_model.R
# [INFO 07-12 18:26:02] Scheduler: Generated all trials that can be generated currently. Model requires more data to generate more trials.
# [INFO 07-12 18:26:02] Scheduler: Retrieved COMPLETED trials: 0 - 4.
# [INFO 07-12 18:26:02] Scheduler: Fetching data for trials: 0 - 4.
# [INFO 2024-07-12 18:26:02,729 MainProcess MainThread {storage.py:303}] boa: Saved optimization parametrization and objective to `[/path/to/your/dir/]/boa_runs_20240712T182558/optimization.csv`.
# [INFO 2024-07-12 18:26:02,742 MainProcess MainThread {storage.py:63}] boa: Saved JSON-serialized state of optimization to `[/path/to/your/dir/]/boa_runs_20240712T182558/scheduler.json`.
# Boa version: 0.10.3.dev20+gb114a5b.d20240705
# [INFO 2024-07-12 18:26:02,751 MainProcess MainThread {scheduler.py:86}] boa: Trials so far: 5
# Currently running trials: []
# Will Produce next trials from generation step: Sobol
# Best trial so far: {4: {'branin': 1.2958629637489611}}
# [INFO 07-12 18:26:03] Scheduler: Running trials [5]...
# [INFO 2024-07-12 18:26:03,300 MainProcess ThreadPoolExecutor-5_0 {script_wrapper.py:322}] boa: Rscript run_model.R
# [INFO 2024-07-12 18:26:03,301 MainProcess ThreadPoolExecutor-5_0 {script_wrapper.py:328}] boa: {'config_path': PosixPath('[/path/to/your/dir/]/config.yaml'), 'config_dir': PosixPath('[/path/to/your/dir/]'), 'config_dir_name': 'r_branin', 'config_file_name': 'config.yaml', 'x0': 5.071101911402133, 'x1': 3.346595736301632, 'trial_dir': PosixPath('[/path/to/your/dir/]/boa_runs_20240712T182558/000005')}
# [INFO 2024-07-12 18:26:03,302 MainProcess ThreadPoolExecutor-5_0 {script_wrapper.py:330}] boa: Rscript run_model.R
# /Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/ax/core/data.py:284: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [INFO 07-12 18:26:04] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 18:26:04] Scheduler: Running trials [6]...
# [INFO 2024-07-12 18:26:04,840 MainProcess ThreadPoolExecutor-6_0 {script_wrapper.py:322}] boa: Rscript run_model.R
# [INFO 2024-07-12 18:26:04,841 MainProcess ThreadPoolExecutor-6_0 {script_wrapper.py:328}] boa: {'config_path': PosixPath('[/path/to/your/dir/]/config.yaml'), 'config_dir': PosixPath('[/path/to/your/dir/]'), 'config_dir_name': 'r_branin', 'config_file_name': 'config.yaml', 'x0': -5.0, 'x1': 10.46185561210404, 'trial_dir': PosixPath('[/path/to/your/dir/]/boa_runs_20240712T182558/000006')}
# [INFO 2024-07-12 18:26:04,842 MainProcess ThreadPoolExecutor-6_0 {script_wrapper.py:330}] boa: Rscript run_model.R
# /Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/ax/core/data.py:284: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [INFO 07-12 18:26:04] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 18:26:05] Scheduler: Running trials [7]...
# [INFO 2024-07-12 18:26:05,551 MainProcess ThreadPoolExecutor-7_0 {script_wrapper.py:322}] boa: Rscript run_model.R
# [INFO 2024-07-12 18:26:05,552 MainProcess ThreadPoolExecutor-7_0 {script_wrapper.py:328}] boa: {'config_path': PosixPath('[/path/to/your/dir/]/config.yaml'), 'config_dir': PosixPath('[/path/to/your/dir/]'), 'config_dir_name': 'r_branin', 'config_file_name': 'config.yaml', 'x0': 6.355541151948184, 'x1': 0.07338314662237432, 'trial_dir': PosixPath('[/path/to/your/dir/]/boa_runs_20240712T182558/000007')}
# [INFO 2024-07-12 18:26:05,553 MainProcess ThreadPoolExecutor-7_0 {script_wrapper.py:330}] boa: Rscript run_model.R
# /Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/ax/core/data.py:284: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [INFO 07-12 18:26:06] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 18:26:06] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-12 18:26:06] Scheduler: Retrieved COMPLETED trials: 5 - 7.
# [INFO 07-12 18:26:06] Scheduler: Fetching data for trials: 5 - 7.
# [INFO 2024-07-12 18:26:06,625 MainProcess MainThread {storage.py:303}] boa: Saved optimization parametrization and objective to `[/path/to/your/dir/]/boa_runs_20240712T182558/optimization.csv`.
# [INFO 2024-07-12 18:26:06,641 MainProcess MainThread {storage.py:63}] boa: Saved JSON-serialized state of optimization to `[/path/to/your/dir/]/boa_runs_20240712T182558/scheduler.json`.
# Boa version: 0.10.3.dev20+gb114a5b.d20240705
# [INFO 2024-07-12 18:26:06,648 MainProcess MainThread {scheduler.py:86}] boa: Trials so far: 8
# Currently running trials: []
# Will Produce next trials from generation step: BoTorch
# Best trial so far: {4: {'branin': 1.2958629637489611}}
# [INFO 07-12 18:26:06] Scheduler: Running trials [8]...
# [INFO 2024-07-12 18:26:06,985 MainProcess ThreadPoolExecutor-8_0 {script_wrapper.py:322}] boa: Rscript run_model.R
# [INFO 2024-07-12 18:26:06,986 MainProcess ThreadPoolExecutor-8_0 {script_wrapper.py:328}] boa: {'config_path': PosixPath('[/path/to/your/dir/]/config.yaml'), 'config_dir': PosixPath('[/path/to/your/dir/]'), 'config_dir_name': 'r_branin', 'config_file_name': 'config.yaml', 'x0': 10.0, 'x1': 4.419443544420957e-17, 'trial_dir': PosixPath('[/path/to/your/dir/]/boa_runs_20240712T182558/000008')}
# [INFO 2024-07-12 18:26:06,987 MainProcess ThreadPoolExecutor-8_0 {script_wrapper.py:330}] boa: Rscript run_model.R
# /Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/ax/core/data.py:284: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [INFO 07-12 18:26:08] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 18:26:08] Scheduler: Running trials [9]...
# [INFO 2024-07-12 18:26:08,531 MainProcess ThreadPoolExecutor-9_0 {script_wrapper.py:322}] boa: Rscript run_model.R
# [INFO 2024-07-12 18:26:08,532 MainProcess ThreadPoolExecutor-9_0 {script_wrapper.py:328}] boa: {'config_path': PosixPath('[/path/to/your/dir/]/config.yaml'), 'config_dir': PosixPath('[/path/to/your/dir/]'), 'config_dir_name': 'r_branin', 'config_file_name': 'config.yaml', 'x0': 3.496857210415536, 'x1': 1.6070833512147744, 'trial_dir': PosixPath('[/path/to/your/dir/]/boa_runs_20240712T182558/000009')}
# [INFO 2024-07-12 18:26:08,533 MainProcess ThreadPoolExecutor-9_0 {script_wrapper.py:330}] boa: Rscript run_model.R
# /Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/ax/core/data.py:284: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [INFO 07-12 18:26:09] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 18:26:10] Scheduler: Running trials [10]...
# [INFO 2024-07-12 18:26:10,160 MainProcess ThreadPoolExecutor-10_0 {script_wrapper.py:322}] boa: Rscript run_model.R
# [INFO 2024-07-12 18:26:10,162 MainProcess ThreadPoolExecutor-10_0 {script_wrapper.py:328}] boa: {'config_path': PosixPath('[/path/to/your/dir/]/config.yaml'), 'config_dir': PosixPath('[/path/to/your/dir/]'), 'config_dir_name': 'r_branin', 'config_file_name': 'config.yaml', 'x0': 3.032450964917654, 'x1': 4.70636634975634, 'trial_dir': PosixPath('[/path/to/your/dir/]/boa_runs_20240712T182558/000010')}
# [INFO 2024-07-12 18:26:10,163 MainProcess ThreadPoolExecutor-10_0 {script_wrapper.py:330}] boa: Rscript run_model.R
# /Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/ax/core/data.py:284: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [INFO 07-12 18:26:10] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 18:26:10] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-12 18:26:10] Scheduler: Retrieved COMPLETED trials: 8 - 9.
# [INFO 07-12 18:26:10] Scheduler: Fetching data for trials: 8 - 9.
# /Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/ax/core/data.py:284: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [INFO 2024-07-12 18:26:10,210 MainProcess MainThread {storage.py:303}] boa: Saved optimization parametrization and objective to `[/path/to/your/dir/]/boa_runs_20240712T182558/optimization.csv`.
# [INFO 2024-07-12 18:26:10,230 MainProcess MainThread {storage.py:63}] boa: Saved JSON-serialized state of optimization to `[/path/to/your/dir/]/boa_runs_20240712T182558/scheduler.json`.
# Boa version: 0.10.3.dev20+gb114a5b.d20240705
# /Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/ax/core/data.py:284: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# /Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/ax/core/data.py:284: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [INFO 2024-07-12 18:26:10,241 MainProcess MainThread {scheduler.py:86}] boa: Trials so far: 11
# Currently running trials: 10
# Will Produce next trials from generation step: BoTorch
# Best trial so far: {9: {'branin': 1.1633848763409738}}
# /Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/ax/core/data.py:284: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [INFO 07-12 18:26:10] Scheduler: Running trials [11]...
# [INFO 2024-07-12 18:26:10,717 MainProcess ThreadPoolExecutor-11_0 {script_wrapper.py:322}] boa: Rscript run_model.R
# [INFO 2024-07-12 18:26:10,718 MainProcess ThreadPoolExecutor-11_0 {script_wrapper.py:328}] boa: {'config_path': PosixPath('[/path/to/your/dir/]/config.yaml'), 'config_dir': PosixPath('[/path/to/your/dir/]'), 'config_dir_name': 'r_branin', 'config_file_name': 'config.yaml', 'x0': 10.0, 'x1': 5.639204157621689, 'trial_dir': PosixPath('[/path/to/your/dir/]/boa_runs_20240712T182558/000011')}
# [INFO 2024-07-12 18:26:10,719 MainProcess ThreadPoolExecutor-11_0 {script_wrapper.py:330}] boa: Rscript run_model.R
# /Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/ax/core/data.py:284: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [INFO 07-12 18:26:11] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 18:26:12] Scheduler: Running trials [12]...
# [INFO 2024-07-12 18:26:12,341 MainProcess ThreadPoolExecutor-12_0 {script_wrapper.py:322}] boa: Rscript run_model.R
# [INFO 2024-07-12 18:26:12,343 MainProcess ThreadPoolExecutor-12_0 {script_wrapper.py:328}] boa: {'config_path': PosixPath('[/path/to/your/dir/]/config.yaml'), 'config_dir': PosixPath('[/path/to/your/dir/]'), 'config_dir_name': 'r_branin', 'config_file_name': 'config.yaml', 'x0': 3.450868730439341, 'x1': 2.846302198226882, 'trial_dir': PosixPath('[/path/to/your/dir/]/boa_runs_20240712T182558/000012')}
# [INFO 2024-07-12 18:26:12,344 MainProcess ThreadPoolExecutor-12_0 {script_wrapper.py:330}] boa: Rscript run_model.R
# /Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/ax/core/data.py:284: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [INFO 07-12 18:26:13] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 18:26:13] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-12 18:26:13] Scheduler: Retrieved COMPLETED trials: 10 - 12.
# [INFO 07-12 18:26:13] Scheduler: Fetching data for trials: 10 - 12.
# [INFO 2024-07-12 18:26:13,417 MainProcess MainThread {storage.py:303}] boa: Saved optimization parametrization and objective to `[/path/to/your/dir/]/boa_runs_20240712T182558/optimization.csv`.
# [INFO 2024-07-12 18:26:13,438 MainProcess MainThread {storage.py:63}] boa: Saved JSON-serialized state of optimization to `[/path/to/your/dir/]/boa_runs_20240712T182558/scheduler.json`.
# Boa version: 0.10.3.dev20+gb114a5b.d20240705
# [INFO 2024-07-12 18:26:13,447 MainProcess MainThread {scheduler.py:86}] boa: Trials so far: 13
# Currently running trials: []
# Will Produce next trials from generation step: BoTorch
# Best trial so far: {9: {'branin': 1.1633848763409738}}
# [INFO 07-12 18:26:13] Scheduler: Running trials [13]...
# [INFO 2024-07-12 18:26:13,953 MainProcess ThreadPoolExecutor-13_0 {script_wrapper.py:322}] boa: Rscript run_model.R
# [INFO 2024-07-12 18:26:13,954 MainProcess ThreadPoolExecutor-13_0 {script_wrapper.py:328}] boa: {'config_path': PosixPath('[/path/to/your/dir/]/config.yaml'), 'config_dir': PosixPath('[/path/to/your/dir/]'), 'config_dir_name': 'r_branin', 'config_file_name': 'config.yaml', 'x0': 3.1399069341141885, 'x1': 2.1161848092406905, 'trial_dir': PosixPath('[/path/to/your/dir/]/boa_runs_20240712T182558/000013')}
# [INFO 2024-07-12 18:26:13,955 MainProcess ThreadPoolExecutor-13_0 {script_wrapper.py:330}] boa: Rscript run_model.R
# /Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/ax/core/data.py:284: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [INFO 07-12 18:26:14] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 18:26:15] Scheduler: Running trials [14]...
# [INFO 2024-07-12 18:26:15,354 MainProcess ThreadPoolExecutor-14_0 {script_wrapper.py:322}] boa: Rscript run_model.R
# [INFO 2024-07-12 18:26:15,356 MainProcess ThreadPoolExecutor-14_0 {script_wrapper.py:328}] boa: {'config_path': PosixPath('[/path/to/your/dir/]/config.yaml'), 'config_dir': PosixPath('[/path/to/your/dir/]'), 'config_dir_name': 'r_branin', 'config_file_name': 'config.yaml', 'x0': 10.0, 'x1': 12.81008956105747, 'trial_dir': PosixPath('[/path/to/your/dir/]/boa_runs_20240712T182558/000014')}
# [INFO 2024-07-12 18:26:15,357 MainProcess ThreadPoolExecutor-14_0 {script_wrapper.py:330}] boa: Rscript run_model.R
# [INFO 07-12 18:26:16] Scheduler: Retrieved COMPLETED trials: 13 - 14.
# [INFO 07-12 18:26:16] Scheduler: Fetching data for trials: 13 - 14.
# [INFO 2024-07-12 18:26:16,415 MainProcess MainThread {storage.py:303}] boa: Saved optimization parametrization and objective to `[/path/to/your/dir/]/boa_runs_20240712T182558/optimization.csv`.
# [INFO 2024-07-12 18:26:16,442 MainProcess MainThread {storage.py:63}] boa: Saved JSON-serialized state of optimization to `[/path/to/your/dir/]/boa_runs_20240712T182558/scheduler.json`.
# Boa version: 0.10.3.dev20+gb114a5b.d20240705
# [INFO 2024-07-12 18:26:16,452 MainProcess MainThread {scheduler.py:86}] boa: Trials so far: 15
# Currently running trials: []
# Will Produce next trials from generation step: BoTorch
# Best trial so far: {13: {'branin': 0.42353965613786393}}
# [INFO 2024-07-12 18:26:16,462 MainProcess MainThread {storage.py:303}] boa: Saved optimization parametrization and objective to `[/path/to/your/dir/]/boa_runs_20240712T182558/optimization.csv`.
# [INFO 2024-07-12 18:26:16,483 MainProcess MainThread {storage.py:63}] boa: Saved JSON-serialized state of optimization to `[/path/to/your/dir/]/boa_runs_20240712T182558/scheduler.json`.
# Boa version: 0.10.3.dev20+gb114a5b.d20240705
# [INFO 2024-07-12 18:26:16,492 MainProcess MainThread {scheduler.py:86}] boa: Trials so far: 15
# Currently running trials: []
# Will Produce next trials from generation step: BoTorch
# Best trial so far: {13: {'branin': 0.42353965613786393}}
# [INFO 2024-07-12 18:26:16,509 MainProcess MainThread {controller.py:188}] boa:
#
# ##############################################
#
# Trials Completed!
# BOA Experiment Run
# Output Experiment Dir: [/path/to/your/dir/]/boa_runs_20240712T182558
# Scheduler File Path: [/path/to/your/dir/]/boa_runs_20240712T182558/scheduler.json
# Optimization CSV File Path: [/path/to/your/dir/]/boa_runs_20240712T182558/optimization.csv
# Start Time: 20240712T182558
# Version: 0.10.3.dev20+gb114a5b.d20240705
# End Time: 20240712T182616
# Total Run Time: 18.065325021743774
#
#     trial_index arm_name trial_status  ...     branin         x0            x1
# 0             0      0_0    COMPLETED  ...  21.615901   0.376986  3.778757e+00
# 1             1      1_0    COMPLETED  ...  22.645076  -0.638923  9.291527e+00
# 2             2      2_0    COMPLETED  ...  36.016358   0.828400  9.188862e+00
# 3             3      3_0    COMPLETED  ...  32.206367   0.914767  6.087045e-01
# 4             4      4_0    COMPLETED  ...   1.295863   2.988574  3.283813e+00
# 5             5      5_0    COMPLETED  ...  17.761651   5.071102  3.346596e+00
# 6             6      6_0    COMPLETED  ...  57.955567  -5.000000  1.046186e+01
# 7             7      7_0    COMPLETED  ...  20.637047   6.355541  7.338315e-02
# 8             8      8_0    COMPLETED  ...  10.960889  10.000000  4.419444e-17
# 9             9      9_0    COMPLETED  ...   1.163385   3.496857  1.607083e+00
# 10           10     10_0    COMPLETED  ...   5.952989   3.032451  4.706366e+00
# 11           11     11_0    COMPLETED  ...   8.892920  10.000000  5.639204e+00
# 12           12     12_0    COMPLETED  ...   1.493810   3.450869  2.846302e+00
# 13           13     13_0    COMPLETED  ...   0.423540   3.139907  2.116185e+00
# 14           14     14_0    COMPLETED  ...  98.123202  10.000000  1.281009e+01
#
# [15 rows x 7 columns]
#
# ##############################################
