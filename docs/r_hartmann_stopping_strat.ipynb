# %% [markdown]
# # R Hartmann6 with Global Stopping Strategy
#
# This notebook is an example of a single objective R model optimization using a Hartmann6 function a global stopping strategy. The Hartmann6 function is a synthetic function that is often used as a stand in for a model that is expensive to evaluate. The function has 6 dimensions and is defined on the unit hypercube.
#
# See the folder `r_hartmann` for the R script and the configuration file.

# %%
# This notebook uses hidden cells to import and display things so
# that it can be ran regullary to make sure the documentation
# is up to date and not broken (as opposed to a markdown file
# that would have an exmaple written once and get out of date
# as the code base changes)

# These hidden cells are only responsible for rerunning
# the documentation to ensure it is correct.
# the actual relavent part of the documentation
# are the non hidden parts

# %%
import pathlib

from IPython.display import Code

boa_paper_dir = pathlib.Path().resolve().parent
r_dir = boa_paper_dir / "r_hartmann"
config_path = r_dir / "config_stopping_strat.yaml"
run_model_script = r_dir / "run_model.R"
hartmann6_script = r_dir / "hartmann6.R"

# %% [markdown]
# ## Configuration File
#
# config_constraints.yaml

# %%
Code(config_path)
# Out:
# objective:
#     metrics:
#         -   name: Hartmann6
#         -   name: rmse
#     outcome_constraints:
#         - l2norm <= 1.25
# parameters:
#     x1:
#         type: range
#         bounds: [0.0, 1.0]
#     x2:
#         type: range
#         bounds: [0.0, 1.0]
#     x3:
#         type: range
#         bounds: [0.0, 1.0]
#     x4:
#         type: range
#         bounds: [0.0, 1.0]
#     x5:
#         type: range
#         bounds: [0.0, 1.0]
#     x6:
#         type: range
#         bounds: [0.0, 1.0]
# parameter_constraints:
#     - .5*x1 + x2 <= 1.5
# n_trials: 10
# script_options:
#     run_model: Rscript run_model.R
# # generation_strategy:
# #     steps:
# #         -   model: SOBOL
# #             num_trials: 10
# #         -   model: GPEI
# #             num_trials: -1

# %% [markdown]
# ## Run Model Wrapper Script
#
# run_model.R

# %%
Code(run_model_script)
# Out:
# # load in any libraries and modules we need
# library(jsonlite)
# source("./hartmann6.R")
#
# trial_dir <- commandArgs(trailingOnly=TRUE)[1]
# data <- read_json(path=file.path(trial_dir, "parameters.json"))
# res <- hartmann6(unlist(data))
# write(toJSON(list(Hartmann6=res)), file.path(trial_dir, "output.json"))

# %% [markdown]
# We also use a function called hartman6 which is a 6 dimensional version of the synthetic hartman function as the stand in for our model function. The code is below. You would substitute this for any call your model, be it local call to your own R model, a system call to a fortran model wrapped in your R script, or perhaps a some code that launches an HPC job and collects the results.
#
# hartmann6.R

# %%
Code(hartmann6_script)
# Out:
# hartmann6 <- function(X) {
#      out <- tryCatch(
#      {
#           alpha <- c(1.0, 1.2, 3.0, 3.2)
#           A <- c(10, 3, 17, 3.5, 1.7, 8,
#                  0.05, 10, 17, 0.1, 8, 14,
#                  3, 3.5, 1.7, 10, 17, 8,
#                  17, 8, 0.05, 10, 0.1, 14)
#           A <- matrix(A, 4, 6, byrow=TRUE)
#           P <- 10^(-4) * c(1312, 1696, 5569, 124, 8283, 5886,
#                            2329, 4135, 8307, 3736, 1004, 9991,
#                            2348, 1451, 3522, 2883, 3047, 6650,
#                            4047, 8828, 8732, 5743, 1091, 381)
#           P <- matrix(P, 4, 6, byrow=TRUE)
#
#           Xmat <- matrix(rep(X,times=4), 4, 6, byrow=TRUE)
#           inner_sum <- rowSums(A[,1:6]*(Xmat-P[,1:6])^2)
#           outer_sum <- sum(alpha * exp(-inner_sum))
#           y <- -outer_sum
#           return(y)
#      },
#        error=function(cond) {
#             return(NA)
#         }
#      )
#     return(out)
# }

# %% [markdown]
# ## Running our script
#
# To run our script we just need to pass the config file to BOA's CLI
#
# ```python
# python -m boa --config-file path/to/config.yaml
# ```
#
# or
#
# ```python
# python -m boa -c path/to/config.yaml
# ```

# %%
# !python -m boa -c {config_path}
# Out:
# [WARNING 07-13 14:27:18] ax.service.utils.with_db_settings_base: Ax currently requires a sqlalchemy version below 2.0. This will be addressed in a future release. Disabling SQL storage in Ax for now, if you would like to use SQL storage please install Ax with mysql extras via `pip install ax-platform[mysql]`.
# [INFO 07-13 14:27:19] ax.service.utils.instantiation: Created search space: SearchSpace(parameters=[RangeParameter(name='x0', parameter_type=FLOAT, range=[0.0, 1.0]), RangeParameter(name='x1', parameter_type=FLOAT, range=[0.0, 1.0]), RangeParameter(name='x2', parameter_type=FLOAT, range=[0.0, 1.0]), RangeParameter(name='x3', parameter_type=FLOAT, range=[0.0, 1.0]), RangeParameter(name='x4', parameter_type=FLOAT, range=[0.0, 1.0]), RangeParameter(name='x5', parameter_type=FLOAT, range=[0.0, 1.0])], parameter_constraints=[]).
# [INFO 07-13 14:27:19] ax.modelbridge.dispatch_utils: Using Models.BOTORCH_MODULAR since there are more ordered parameters than there are categories for the unordered categorical parameters.
# [INFO 07-13 14:27:19] ax.modelbridge.dispatch_utils: Calculating the number of remaining initialization trials based on num_initialization_trials=None max_initialization_trials=None num_tunable_parameters=6 num_trials=None use_batch_trials=False
# [INFO 07-13 14:27:19] ax.modelbridge.dispatch_utils: calculated num_initialization_trials=12
# [INFO 07-13 14:27:19] ax.modelbridge.dispatch_utils: num_completed_initialization_trials=0 num_remaining_initialization_trials=12
# [INFO 07-13 14:27:19] ax.modelbridge.dispatch_utils: `verbose`, `disable_progbar`, and `jit_compile` are not yet supported when using `choose_generation_strategy` with ModularBoTorchModel, dropping these arguments.
# [INFO 07-13 14:27:19] ax.modelbridge.dispatch_utils: Using Bayesian Optimization generation strategy: GenerationStrategy(name='Sobol+BoTorch', steps=[Sobol for 12 trials, BoTorch for subsequent trials]). Iterations after 12 will take longer to generate due to model-fitting.
# [INFO 07-13 14:27:19] Scheduler: `Scheduler` requires experiment to have immutable search space and optimization config. Setting property immutable_search_space_and_opt_config to `True` on experiment.
# [INFO 2024-07-13 14:27:19,407 MainProcess MainThread {controller.py:165}] boa:
#
# ##############################################
#
#
# BOA Experiment Run
# Output Experiment Dir: /Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann/r_hartmann_10_trials_w_stopping_strategy_20240713T142719
# Scheduler File Path: /Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann/r_hartmann_10_trials_w_stopping_strategy_20240713T142719/scheduler.json
# Optimization CSV File Path: /Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann/r_hartmann_10_trials_w_stopping_strategy_20240713T142719/optimization.csv
# Start Time: 20240713T142719
# Version: 0.10.3.dev20+gb114a5b.d20240705
#
# ##############################################
#
# [INFO 07-13 14:27:19] Scheduler: Running trials [0]...
# [INFO 2024-07-13 14:27:19,413 MainProcess ThreadPoolExecutor-0_0 {script_wrapper.py:322}] boa: Rscript run_model.R
# [INFO 2024-07-13 14:27:19,415 MainProcess ThreadPoolExecutor-0_0 {script_wrapper.py:328}] boa: {'config_path': PosixPath('/Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann/config_stopping_strat.yaml'), 'config_dir': PosixPath('/Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann'), 'config_dir_name': 'r_hartmann', 'config_file_name': 'config_stopping_strat.yaml', 'x0': 0.26511478424072266, 'x1': 0.37809351086616516, 'x2': 0.09526261687278748, 'x3': 0.2258318066596985, 'x4': 0.3487871289253235, 'x5': 0.39134272933006287, 'trial_dir': PosixPath('/Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann/r_hartmann_10_trials_w_stopping_strategy_20240713T142719/000000')}
# [INFO 2024-07-13 14:27:19,415 MainProcess ThreadPoolExecutor-0_0 {script_wrapper.py:330}] boa: Rscript run_model.R
# [INFO 07-13 14:27:20] Scheduler: Running trials [1]...
# [INFO 2024-07-13 14:27:20,450 MainProcess ThreadPoolExecutor-1_0 {script_wrapper.py:322}] boa: Rscript run_model.R
# [INFO 2024-07-13 14:27:20,451 MainProcess ThreadPoolExecutor-1_0 {script_wrapper.py:328}] boa: {'config_path': PosixPath('/Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann/config_stopping_strat.yaml'), 'config_dir': PosixPath('/Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann'), 'config_dir_name': 'r_hartmann', 'config_file_name': 'config_stopping_strat.yaml', 'x0': 0.6565033858641982, 'x1': 0.17925372906029224, 'x2': 0.7871429547667503, 'x3': 0.9361818386241794, 'x4': 0.6746745919808745, 'x5': 0.8423831360414624, 'trial_dir': PosixPath('/Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann/r_hartmann_10_trials_w_stopping_strategy_20240713T142719/000001')}
# [INFO 2024-07-13 14:27:20,452 MainProcess ThreadPoolExecutor-1_0 {script_wrapper.py:330}] boa: Rscript run_model.R
# [INFO 07-13 14:27:20] Scheduler: Running trials [2]...
# [INFO 2024-07-13 14:27:20,479 MainProcess ThreadPoolExecutor-2_0 {script_wrapper.py:322}] boa: Rscript run_model.R
# [INFO 2024-07-13 14:27:20,479 MainProcess ThreadPoolExecutor-2_0 {script_wrapper.py:328}] boa: {'config_path': PosixPath('/Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann/config_stopping_strat.yaml'), 'config_dir': PosixPath('/Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann'), 'config_dir_name': 'r_hartmann', 'config_file_name': 'config_stopping_strat.yaml', 'x0': 0.05291349161416292, 'x1': 0.10376106668263674, 'x2': 0.9924535695463419, 'x3': 0.04792424477636814, 'x4': 0.0656417403370142, 'x5': 0.04358655586838722, 'trial_dir': PosixPath('/Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann/r_hartmann_10_trials_w_stopping_strategy_20240713T142719/000002')}
# [INFO 2024-07-13 14:27:20,480 MainProcess ThreadPoolExecutor-2_0 {script_wrapper.py:330}] boa: Rscript run_model.R
# [INFO 07-13 14:27:20] Scheduler: Running trials [3]...
# [INFO 2024-07-13 14:27:20,501 MainProcess ThreadPoolExecutor-3_0 {script_wrapper.py:322}] boa: Rscript run_model.R
# [INFO 2024-07-13 14:27:20,502 MainProcess ThreadPoolExecutor-3_0 {script_wrapper.py:328}] boa: {'config_path': PosixPath('/Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann/config_stopping_strat.yaml'), 'config_dir': PosixPath('/Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann'), 'config_dir_name': 'r_hartmann', 'config_file_name': 'config_stopping_strat.yaml', 'x0': 0.4303607093170285, 'x1': 0.09873613622039557, 'x2': 0.532562218606472, 'x3': 0.9916326319798827, 'x4': 0.6543588014319539, 'x5': 0.4537770450115204, 'trial_dir': PosixPath('/Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann/r_hartmann_10_trials_w_stopping_strategy_20240713T142719/000003')}
# [INFO 2024-07-13 14:27:20,503 MainProcess ThreadPoolExecutor-3_0 {script_wrapper.py:330}] boa: Rscript run_model.R
# [INFO 07-13 14:27:21] Scheduler: Running trials [4]...
# [INFO 2024-07-13 14:27:21,528 MainProcess ThreadPoolExecutor-4_0 {script_wrapper.py:322}] boa: Rscript run_model.R
# [INFO 2024-07-13 14:27:21,529 MainProcess ThreadPoolExecutor-4_0 {script_wrapper.py:328}] boa: {'config_path': PosixPath('/Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann/config_stopping_strat.yaml'), 'config_dir': PosixPath('/Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann'), 'config_dir_name': 'r_hartmann', 'config_file_name': 'config_stopping_strat.yaml', 'x0': 0.24413189943879843, 'x1': 0.7968560382723808, 'x2': 0.9278521062806249, 'x3': 0.8415602538734674, 'x4': 0.07717610895633698, 'x5': 0.9427136480808258, 'trial_dir': PosixPath('/Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann/r_hartmann_10_trials_w_stopping_strategy_20240713T142719/000004')}
# [INFO 2024-07-13 14:27:21,530 MainProcess ThreadPoolExecutor-4_0 {script_wrapper.py:330}] boa: Rscript run_model.R
# [INFO 07-13 14:27:22] Scheduler: Running trials [5]...
# [INFO 2024-07-13 14:27:22,570 MainProcess ThreadPoolExecutor-5_0 {script_wrapper.py:322}] boa: Rscript run_model.R
# [INFO 2024-07-13 14:27:22,571 MainProcess ThreadPoolExecutor-5_0 {script_wrapper.py:328}] boa: {'config_path': PosixPath('/Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann/config_stopping_strat.yaml'), 'config_dir': PosixPath('/Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann'), 'config_dir_name': 'r_hartmann', 'config_file_name': 'config_stopping_strat.yaml', 'x0': 0.9291246989741921, 'x1': 0.3355550467967987, 'x2': 0.8054029680788517, 'x3': 0.3567602578550577, 'x4': 0.7655640076845884, 'x5': 0.925491645000875, 'trial_dir': PosixPath('/Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann/r_hartmann_10_trials_w_stopping_strategy_20240713T142719/000005')}
# [INFO 2024-07-13 14:27:22,572 MainProcess ThreadPoolExecutor-5_0 {script_wrapper.py:330}] boa: Rscript run_model.R
# [INFO 07-13 14:27:22] Scheduler: Running trials [6]...
# [INFO 2024-07-13 14:27:22,601 MainProcess ThreadPoolExecutor-6_0 {script_wrapper.py:322}] boa: Rscript run_model.R
# [INFO 2024-07-13 14:27:22,603 MainProcess ThreadPoolExecutor-6_0 {script_wrapper.py:328}] boa: {'config_path': PosixPath('/Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann/config_stopping_strat.yaml'), 'config_dir': PosixPath('/Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann'), 'config_dir_name': 'r_hartmann', 'config_file_name': 'config_stopping_strat.yaml', 'x0': 0.4794069118797779, 'x1': 0.19350381195545197, 'x2': 0.26832016836851835, 'x3': 0.14704703632742167, 'x4': 0.2876370530575514, 'x5': 0.367081543430686, 'trial_dir': PosixPath('/Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann/r_hartmann_10_trials_w_stopping_strategy_20240713T142719/000006')}
# [INFO 2024-07-13 14:27:22,605 MainProcess ThreadPoolExecutor-6_0 {script_wrapper.py:330}] boa: Rscript run_model.R
# [INFO 07-13 14:27:22] Scheduler: Running trials [7]...
# [INFO 2024-07-13 14:27:22,633 MainProcess ThreadPoolExecutor-7_0 {script_wrapper.py:322}] boa: Rscript run_model.R
# [INFO 2024-07-13 14:27:22,636 MainProcess ThreadPoolExecutor-7_0 {script_wrapper.py:328}] boa: {'config_path': PosixPath('/Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann/config_stopping_strat.yaml'), 'config_dir': PosixPath('/Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann'), 'config_dir_name': 'r_hartmann', 'config_file_name': 'config_stopping_strat.yaml', 'x0': 0.8995465198531747, 'x1': 0.7703491952270269, 'x2': 0.81408625934273, 'x3': 0.08370104897767305, 'x4': 0.5671213418245316, 'x5': 0.9341383595019579, 'trial_dir': PosixPath('/Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann/r_hartmann_10_trials_w_stopping_strategy_20240713T142719/000007')}
# [INFO 2024-07-13 14:27:22,637 MainProcess ThreadPoolExecutor-7_0 {script_wrapper.py:330}] boa: Rscript run_model.R
# [INFO 07-13 14:27:23] Scheduler: Running trials [8]...
# [INFO 2024-07-13 14:27:23,680 MainProcess ThreadPoolExecutor-8_0 {script_wrapper.py:322}] boa: Rscript run_model.R
# [INFO 2024-07-13 14:27:23,681 MainProcess ThreadPoolExecutor-8_0 {script_wrapper.py:328}] boa: {'config_path': PosixPath('/Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann/config_stopping_strat.yaml'), 'config_dir': PosixPath('/Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann'), 'config_dir_name': 'r_hartmann', 'config_file_name': 'config_stopping_strat.yaml', 'x0': 0.3030482726171613, 'x1': 0.8250605771318078, 'x2': 0.8103750692680478, 'x3': 0.6022584270685911, 'x4': 0.48096241895109415, 'x5': 0.7590443827211857, 'trial_dir': PosixPath('/Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann/r_hartmann_10_trials_w_stopping_strategy_20240713T142719/000008')}
# [INFO 2024-07-13 14:27:23,683 MainProcess ThreadPoolExecutor-8_0 {script_wrapper.py:330}] boa: Rscript run_model.R
# [INFO 07-13 14:27:23] Scheduler: Running trials [9]...
# [INFO 2024-07-13 14:27:23,711 MainProcess ThreadPoolExecutor-9_0 {script_wrapper.py:322}] boa: Rscript run_model.R
# [INFO 2024-07-13 14:27:23,713 MainProcess ThreadPoolExecutor-9_0 {script_wrapper.py:328}] boa: {'config_path': PosixPath('/Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann/config_stopping_strat.yaml'), 'config_dir': PosixPath('/Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann'), 'config_dir_name': 'r_hartmann', 'config_file_name': 'config_stopping_strat.yaml', 'x0': 0.6348701007664204, 'x1': 0.5474590547382832, 'x2': 0.42332294024527073, 'x3': 0.39308795891702175, 'x4': 0.7401072606444359, 'x5': 0.14322073571383953, 'trial_dir': PosixPath('/Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann/r_hartmann_10_trials_w_stopping_strategy_20240713T142719/000009')}
# [INFO 2024-07-13 14:27:23,714 MainProcess ThreadPoolExecutor-9_0 {script_wrapper.py:330}] boa: Rscript run_model.R
# [INFO 07-13 14:27:24] Scheduler: Retrieved COMPLETED trials: 0 - 9.
# [INFO 07-13 14:27:24] Scheduler: Fetching data for trials: 0 - 9.
# [ERROR 2024-07-13 14:27:24,750 MainProcess MainThread {metaclasses.py:33}] boa: Boa Wrapper encountered Exception: ValueError('found extra returned metric: l2norm in returned metrics from fetch_trial_dataCheck the name of your metrics in your config file line up with the metric names you return from your wrapper class or wrapper script.') in _fetch_trial_data
# Traceback (most recent call last):
#   File "/Users/madelinescyphers/Documents/projs_.nosync/BO/boa/boa/metaclasses.py", line 31, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/madelinescyphers/Documents/projs_.nosync/BO/boa/boa/wrappers/wrapper_utils.py", line 129, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/madelinescyphers/Documents/projs_.nosync/BO/boa/boa/wrappers/base_wrapper.py", line 430, in _fetch_trial_data
#     raise ValueError(
# ValueError: found extra returned metric: l2norm in returned metrics from fetch_trial_dataCheck the name of your metrics in your config file line up with the metric names you return from your wrapper class or wrapper script.
# [ERROR 2024-07-13 14:27:24,755 MainProcess MainThread {metaclasses.py:33}] boa: Boa Wrapper encountered Exception: ValueError('found extra returned metric: l2norm in returned metrics from fetch_trial_dataCheck the name of your metrics in your config file line up with the metric names you return from your wrapper class or wrapper script.') in _fetch_trial_data
# Traceback (most recent call last):
#   File "/Users/madelinescyphers/Documents/projs_.nosync/BO/boa/boa/metaclasses.py", line 31, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/madelinescyphers/Documents/projs_.nosync/BO/boa/boa/wrappers/wrapper_utils.py", line 129, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/madelinescyphers/Documents/projs_.nosync/BO/boa/boa/metaclasses.py", line 31, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/madelinescyphers/Documents/projs_.nosync/BO/boa/boa/wrappers/wrapper_utils.py", line 129, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/madelinescyphers/Documents/projs_.nosync/BO/boa/boa/wrappers/base_wrapper.py", line 430, in _fetch_trial_data
#     raise ValueError(
# ValueError: found extra returned metric: l2norm in returned metrics from fetch_trial_dataCheck the name of your metrics in your config file line up with the metric names you return from your wrapper class or wrapper script.
# [INFO 07-13 14:27:24] ax.service.utils.report_utils: No results present for the specified metrics `[PassThrough('Hartmann6')]`. Returning arm parameters and metadata only.
# [INFO 2024-07-13 14:27:24,775 MainProcess MainThread {controller.py:188}] boa:
#
# ##############################################
#
# Error Completing because of ValueError('found extra returned metric: l2norm in returned metrics from fetch_trial_dataCheck the name of your metrics in your config file line up with the metric names you return from your wrapper class or wrapper script.')
# BOA Experiment Run
# Output Experiment Dir: /Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann/r_hartmann_10_trials_w_stopping_strategy_20240713T142719
# Scheduler File Path: /Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann/r_hartmann_10_trials_w_stopping_strategy_20240713T142719/scheduler.json
# Optimization CSV File Path: /Users/madelinescyphers/Documents/projs_.nosync/BO/BOA-paper/r_hartmann/r_hartmann_10_trials_w_stopping_strategy_20240713T142719/optimization.csv
# Start Time: 20240713T142719
# Version: 0.10.3.dev20+gb114a5b.d20240705
# End Time: 20240713T142724
# Total Run Time: 5.34997296333313
#
#    trial_index arm_name trial_status  ...        x3        x4        x5
# 0            0      0_0    COMPLETED  ...  0.225832  0.348787  0.391343
# 1            1      1_0    COMPLETED  ...  0.936182  0.674675  0.842383
# 2            2      2_0    COMPLETED  ...  0.047924  0.065642  0.043587
# 3            3      3_0    COMPLETED  ...  0.991633  0.654359  0.453777
# 4            4      4_0    COMPLETED  ...  0.841560  0.077176  0.942714
# 5            5      5_0    COMPLETED  ...  0.356760  0.765564  0.925492
# 6            6      6_0    COMPLETED  ...  0.147047  0.287637  0.367082
# 7            7      7_0    COMPLETED  ...  0.083701  0.567121  0.934138
# 8            8      8_0    COMPLETED  ...  0.602258  0.480962  0.759044
# 9            9      9_0    COMPLETED  ...  0.393088  0.740107  0.143221
#
# [10 rows x 10 columns]
#
# ##############################################
#
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/madelinescyphers/Documents/projs_.nosync/BO/boa/boa/__main__.py", line 219, in <module>
#     main()
#   File "/Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/click/core.py", line 1157, in __call__
#     return self.main(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/click/core.py", line 1078, in main
#     rv = self.invoke(ctx)
#          ^^^^^^^^^^^^^^^^
#   File "/Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/click/core.py", line 1434, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/click/core.py", line 783, in invoke
#     return __callback(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/madelinescyphers/Documents/projs_.nosync/BO/boa/boa/__main__.py", line 83, in main
#     return run(config_path, scheduler_path=scheduler_path, wrapper_path=wrapper_path, rel_to_config=rel_to_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/madelinescyphers/Documents/projs_.nosync/BO/boa/boa/__main__.py", line 159, in run
#     scheduler = controller.run()
#                 ^^^^^^^^^^^^^^^^
#   File "/Users/madelinescyphers/Documents/projs_.nosync/BO/boa/boa/controller.py", line 181, in run
#     scheduler.run_n_trials(self.config.n_trials)
#   File "/Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/ax/service/scheduler.py", line 958, in run_n_trials
#     for _ in self.run_trials_and_yield_results(
#   File "/Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/ax/service/scheduler.py", line 890, in run_trials_and_yield_results
#     yield self.wait_for_completed_trials_and_report_results(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/ax/service/scheduler.py", line 672, in wait_for_completed_trials_and_report_results
#     while len(self.pending_trials) > 0 and not self.poll_and_process_results():
#                                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/ax/service/scheduler.py", line 1234, in poll_and_process_results
#     self._process_completed_trials(newly_completed=newly_completed)
#   File "/Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/ax/service/scheduler.py", line 1254, in _process_completed_trials
#     self._fetch_and_process_trials_data_results(trial_indices=newly_completed)
#   File "/Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/ax/service/scheduler.py", line 1746, in _fetch_and_process_trials_data_results
#     results = self.experiment.fetch_trials_data_results(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/ax/core/experiment.py", line 506, in fetch_trials_data_results
#     return self._lookup_or_fetch_trials_results(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/ax/core/experiment.py", line 630, in _lookup_or_fetch_trials_results
#     ) = first_metric_of_group.fetch_data_prefer_lookup(
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/ax/core/metric.py", line 313, in fetch_data_prefer_lookup
#     fetched_trial_data = self.bulk_fetch_experiment_data(
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/ax/core/metric.py", line 220, in bulk_fetch_experiment_data
#     return {
#            ^
#   File "/Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/ax/core/metric.py", line 221, in <dictcomp>
#     trial.index: self.bulk_fetch_trial_data(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/ax/core/metric.py", line 192, in bulk_fetch_trial_data
#     return self.__class__.fetch_experiment_data_multi(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/ax/core/metric.py", line 385, in fetch_experiment_data_multi
#     return {
#            ^
#   File "/Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/ax/core/metric.py", line 386, in <dictcomp>
#     trial.index: cls.fetch_trial_data_multi(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/ax/core/metric.py", line 364, in fetch_trial_data_multi
#     return {
#            ^
#   File "/Users/madelinescyphers/mambaforge/envs/boa-dev/lib/python3.11/site-packages/ax/core/metric.py", line 365, in <dictcomp>
#     metric.name: metric.fetch_trial_data(trial=trial, **kwargs)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/madelinescyphers/Documents/projs_.nosync/BO/boa/boa/metrics/modular_metric.py", line 174, in fetch_trial_data
#     self.wrapper._fetch_trial_data(
#   File "/Users/madelinescyphers/Documents/projs_.nosync/BO/boa/boa/metaclasses.py", line 31, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/madelinescyphers/Documents/projs_.nosync/BO/boa/boa/wrappers/wrapper_utils.py", line 129, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/madelinescyphers/Documents/projs_.nosync/BO/boa/boa/metaclasses.py", line 31, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/madelinescyphers/Documents/projs_.nosync/BO/boa/boa/wrappers/wrapper_utils.py", line 129, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/madelinescyphers/Documents/projs_.nosync/BO/boa/boa/wrappers/base_wrapper.py", line 430, in _fetch_trial_data
#     raise ValueError(
# ValueError: found extra returned metric: l2norm in returned metrics from fetch_trial_dataCheck the name of your metrics in your config file line up with the metric names you return from your wrapper class or wrapper script.

# %%
output = !python -m boa -c {config_path}  # we capture ipython terminal output to python variable
o = "\n".join(ln for ln in output)  # it comes in as a list, we convert to string
o = o.replace(str(r_dir),  "[/path/to/your/dir/]")  # replace the actual dir with a stand in for privacy reasons
Code(o)
# Out:
# ^C
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}
